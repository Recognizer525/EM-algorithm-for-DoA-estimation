# %%
import numpy as np

# %%
from pathlib import Path
import sys

try:
    ROOT = Path().resolve().parents[1]
    assert (ROOT / "common").exists()
except AssertionError:
    ROOT = next(p for p in Path().resolve().parents if (p / "common").exists())

if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
#print(ROOT)

# %%
from common import sensors as sn 
from common import subspace_methods as sm
from common import em_tools as em
from common import log_funcs as lf

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12

failing_sensors1 = np.arange(5)
gap_ratio1 = 0.5 * np.ones_like(failing_sensors1, dtype=np.float32)

theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sn.gss(Num_emitters1, sample_size1, P1)
N1 = sn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sn.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sn.initial_Cov(X1_with_mv)
MUSIC_theta1 = sm.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sn.SNR(A1, P1, Q1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = em.multistart_EM(X1_with_mv, 
                                                                        Num_emitters1, 
                                                                        Q=Q1,
                                                                        theta_guess=MUSIC_theta1, 
                                                                        num_of_starts=10, 
                                                                        max_iter=20, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.71558499],P=[[1.18642836e-07-1.98523347e-24j]]
# Inital likelihood = -870.4011155592349
# Iteration=1
# new_angles=[0.72207638]
# likelihood is -870.3923458919232 on iteration 1.
# Iteration=2
# new_angles=[0.71688292]
# likelihood is -870.3823384183634 on iteration 2.
# Iteration=3
# new_angles=[0.71263946]
# likelihood is -870.3716161652848 on iteration 3.
# Iteration=4
# new_angles=[0.70942051]
# likelihood is -870.36058408191 on iteration 4.
# Iteration=5
# new_angles=[0.70684918]
# likelihood is -870.3493318859014 on iteration 5.
# Iteration=6
# new_angles=[0.70492438]
# likelihood is -870.3379335257465 on iteration 6.
# Iteration=7
# new_angles=[0.70328208]
# likelihood is -870.3262830013847 on iteration 7.
# Iteration=8
# new_angles=[0.70200241]
# likelihood is -870.3143725697234 on iteration 8.
# Iteration=9
# new_angles=[0.70090075]
# likelihood is -870.3020922424195 on iteration 9.
# Iteration=10
# new_angles=[0.69990221]
# likelihood is -870.2893507361222 on iteration 10.
# Iteration=11
# new_angles=[0.69922347]
# likelihood is -870.2761022094676 on iteration 11.
# Iteration=12
# new_angles=[0.6986774]
# likelihood is -870.2621877708159 on iteration 12.
# Iteration=13
# new_angles=[0.6982753]
# likelihood is -870.2474739640802 on iteration 13.
# Iteration=14
# new_angles=[0.69790237]
# likelihood is -870.2317814873643 on iteration 14.
# Iteration=15
# new_angles=[0.69758696]
# likelihood is -870.214923663855 on iteration 15.
# Iteration=16
# new_angles=[0.69736009]
# likelihood is -870.1966691453749 on iteration 16.
# Iteration=17
# new_angles=[0.69721663]
# likelihood is -870.176725910575 on iteration 17.
# Iteration=18
# new_angles=[0.69707319]
# likelihood is -870.1547220875138 on iteration 18.
# Iteration=19
# new_angles=[0.69693084]
# likelihood is -870.1301977104869 on iteration 19.
# Iteration=20
# new_angles=[0.69687666]
# likelihood is -870.1025648674348 on iteration 20.
# 1-th start
# theta=[0.75761751],P=[[7.62531873e-08-2.64697796e-24j]]
# Inital likelihood = -870.4011243940959
# Iteration=1
# new_angles=[0.75761751]
# likelihood is -870.3979113359053 on iteration 1.
# Iteration=2
# new_angles=[0.74559077]
# likelihood is -870.3910144962929 on iteration 2.
# Iteration=3
# new_angles=[0.73551859]
# likelihood is -870.3809812822103 on iteration 3.
# Iteration=4
# new_angles=[0.72764432]
# likelihood is -870.3692426879422 on iteration 4.
# Iteration=5
# new_angles=[0.72121794]
# likelihood is -870.3565785790346 on iteration 5.
# Iteration=6
# new_angles=[0.7161215]
# likelihood is -870.3436563343245 on iteration 6.
# Iteration=7
# new_angles=[0.71223682]
# likelihood is -870.3307983459454 on iteration 7.
# Iteration=8
# new_angles=[0.70901899]
# likelihood is -870.3178114374508 on iteration 8.
# Iteration=9
# new_angles=[0.70662601]
# likelihood is -870.3048190656855 on iteration 9.
# Iteration=10
# new_angles=[0.70464704]
# likelihood is -870.2915303962229 on iteration 10.
# Iteration=11
# new_angles=[0.70304903]
# likelihood is -870.2778473332498 on iteration 11.
# Iteration=12
# new_angles=[0.70176961]
# likelihood is -870.2636245799192 on iteration 12.
# Iteration=13
# new_angles=[0.7007566]
# likelihood is -870.2486976730361 on iteration 13.
# Iteration=14
# new_angles=[0.69997416]
# likelihood is -870.2328836284718 on iteration 14.
# Iteration=15
# new_angles=[0.69929538]
# likelihood is -870.2159408834625 on iteration 15.
# Iteration=16
# new_angles=[0.69883275]
# likelihood is -870.1976663713403 on iteration 16.
# Iteration=17
# new_angles=[0.69837138]
# likelihood is -870.1777065917476 on iteration 17.
# Iteration=18
# new_angles=[0.69801214]
# likelihood is -870.1557284797804 on iteration 18.
# Iteration=19
# new_angles=[0.6976967]
# likelihood is -870.1312588620561 on iteration 19.
# Iteration=20
# new_angles=[0.69738134]
# likelihood is -870.103699907698 on iteration 20.
# 2-th start
# theta=[0.75275765],P=[[4.72357604e-08-5.62482817e-24j]]
# Inital likelihood = -870.4011249844442
# Iteration=1
# new_angles=[0.75275765]
# likelihood is -870.397209414167 on iteration 1.
# Iteration=2
# new_angles=[0.7421057]
# likelihood is -870.3898908282724 on iteration 2.
# Iteration=3
# new_angles=[0.73286991]
# likelihood is -870.3797210959124 on iteration 3.
# Iteration=4
# new_angles=[0.72551978]
# likelihood is -870.3680151180776 on iteration 4.
# Iteration=5
# new_angles=[0.71965356]
# likelihood is -870.3555988928787 on iteration 5.
# Iteration=6
# new_angles=[0.71497195]
# likelihood is -870.3429273677839 on iteration 6.
# Iteration=7
# new_angles=[0.71119138]
# likelihood is -870.330150914256 on iteration 7.
# Iteration=8
# new_angles=[0.70825376]
# likelihood is -870.3173619047499 on iteration 8.
# Iteration=9
# new_angles=[0.70592194]
# likelihood is -870.3044295605781 on iteration 9.
# Iteration=10
# new_angles=[0.70409083]
# likelihood is -870.2912421996101 on iteration 10.
# Iteration=11
# new_angles=[0.70258242]
# likelihood is -870.2776220105173 on iteration 11.
# Iteration=12
# new_angles=[0.70139547]
# likelihood is -870.2634540610883 on iteration 12.
# Iteration=13
# new_angles=[0.70042967]
# likelihood is -870.2485565995586 on iteration 13.
# Iteration=14
# new_angles=[0.69964745]
# likelihood is -870.2327513494442 on iteration 14.
# Iteration=15
# new_angles=[0.69901259]
# likelihood is -870.2158295719421 on iteration 15.
# Iteration=16
# new_angles=[0.69855116]
# likelihood is -870.1975586155047 on iteration 16.
# Iteration=17
# new_angles=[0.6981491]
# likelihood is -870.1776167744307 on iteration 17.
# Iteration=18
# new_angles=[0.697823]
# likelihood is -870.1556466204124 on iteration 18.
# Iteration=19
# new_angles=[0.69758521]
# likelihood is -870.1311906495679 on iteration 19.
# Iteration=20
# new_angles=[0.69735834]
# likelihood is -870.103643085259 on iteration 20.
# 3-th start
# theta=[0.82383174],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011268160693
# Iteration=1
# new_angles=[0.82383174]
# likelihood is -870.4010971310913 on iteration 1.
# Likelihood is converged!
# 4-th start
# theta=[0.72131738],P=[[1.09961713e-07-2.97785021e-24j]]
# Inital likelihood = -870.4011171320063
# Iteration=1
# new_angles=[0.7278417]
# likelihood is -870.3931694341323 on iteration 1.
# Iteration=2
# new_angles=[0.7214142]
# likelihood is -870.3834459849502 on iteration 2.
# Iteration=3
# new_angles=[0.71631688]
# likelihood is -870.372742500811 on iteration 3.
# Iteration=4
# new_angles=[0.71243907]
# likelihood is -870.3616111038483 on iteration 4.
# Iteration=5
# new_angles=[0.70921746]
# likelihood is -870.3501649770304 on iteration 5.
# Iteration=6
# new_angles=[0.70664978]
# likelihood is -870.3385426833912 on iteration 6.
# Iteration=7
# new_angles=[0.70472531]
# likelihood is -870.326782175174 on iteration 7.
# Iteration=8
# new_angles=[0.70308329]
# likelihood is -870.3147371453013 on iteration 8.
# Iteration=9
# new_angles=[0.70180704]
# likelihood is -870.3023866227653 on iteration 9.
# Iteration=10
# new_angles=[0.700794]
# likelihood is -870.2896205780465 on iteration 10.
# Iteration=11
# new_angles=[0.70001154]
# likelihood is -870.276333297745 on iteration 11.
# Iteration=12
# new_angles=[0.69936585]
# likelihood is -870.2623860486955 on iteration 12.
# Iteration=13
# new_angles=[0.69873115]
# likelihood is -870.2476184158311 on iteration 13.
# Iteration=14
# new_angles=[0.69826982]
# likelihood is -870.2319067991813 on iteration 14.
# Iteration=15
# new_angles=[0.69789689]
# likelihood is -870.2150387758672 on iteration 15.
# Iteration=16
# new_angles=[0.69758149]
# likelihood is -870.1967739346132 on iteration 16.
# Iteration=17
# new_angles=[0.69735462]
# likelihood is -870.1768258760203 on iteration 17.
# Iteration=18
# new_angles=[0.69721116]
# likelihood is -870.154829284021 on iteration 18.
# Iteration=19
# new_angles=[0.69706772]
# likelihood is -870.1303134510449 on iteration 19.
# Iteration=20
# new_angles=[0.69692537]
# likelihood is -870.1026847821864 on iteration 20.
# 5-th start
# theta=[0.69420695],P=[[2.63712642e-07-3.97046694e-24j]]
# Inital likelihood = -870.4010990043953
# Iteration=1
# new_angles=[0.69420695]
# likelihood is -870.3903485197766 on iteration 1.
# Iteration=2
# new_angles=[0.69447058]
# likelihood is -870.3797792032293 on iteration 2.
# Iteration=3
# new_angles=[0.69473427]
# likelihood is -870.3691471792129 on iteration 3.
# Iteration=4
# new_angles=[0.69501169]
# likelihood is -870.3584077712488 on iteration 4.
# Iteration=5
# new_angles=[0.69510317]
# likelihood is -870.3475207677365 on iteration 5.
# Iteration=6
# new_angles=[0.69536699]
# likelihood is -870.3364207135667 on iteration 6.
# Iteration=7
# new_angles=[0.69560189]
# likelihood is -870.3250575319364 on iteration 7.
# Iteration=8
# new_angles=[0.69577775]
# likelihood is -870.3133676772391 on iteration 8.
# Iteration=9
# new_angles=[0.69586929]
# likelihood is -870.3012784286948 on iteration 9.
# Iteration=10
# new_angles=[0.69596083]
# likelihood is -870.2887033431552 on iteration 10.
# Iteration=11
# new_angles=[0.69605238]
# likelihood is -870.2755458043212 on iteration 11.
# Iteration=12
# new_angles=[0.69614393]
# likelihood is -870.2616930406448 on iteration 12.
# Iteration=13
# new_angles=[0.6962355]
# likelihood is -870.2470119533629 on iteration 13.
# Iteration=14
# new_angles=[0.69623868]
# likelihood is -870.2313447898877 on iteration 14.
# Iteration=15
# new_angles=[0.69624187]
# likelihood is -870.2144982303026 on iteration 15.
# Iteration=16
# new_angles=[0.69624505]
# likelihood is -870.1962378035311 on iteration 16.
# Iteration=17
# new_angles=[0.69624823]
# likelihood is -870.1762734526739 on iteration 17.
# Iteration=18
# new_angles=[0.69625142]
# likelihood is -870.1542415497103 on iteration 18.
# Iteration=19
# new_angles=[0.6962546]
# likelihood is -870.129679652705 on iteration 19.
# Iteration=20
# new_angles=[0.69625779]
# likelihood is -870.1019903949427 on iteration 20.
# 6-th start
# theta=[0.72207198],P=[[1.08695785e-07+1.65436123e-24j]]
# Inital likelihood = -870.4011173514194
# Iteration=1
# new_angles=[0.72860067]
# likelihood is -870.3932848723766 on iteration 1.
# Iteration=2
# new_angles=[0.72170859]
# likelihood is -870.383523752868 on iteration 2.
# Iteration=3
# new_angles=[0.71660997]
# likelihood is -870.3728406386797 on iteration 3.
# Iteration=4
# new_angles=[0.71273118]
# likelihood is -870.3617205850892 on iteration 4.
# Iteration=5
# new_angles=[0.70951197]
# likelihood is -870.3502791275841 on iteration 5.
# Iteration=6
# new_angles=[0.70694365]
# likelihood is -870.3386554458052 on iteration 6.
# Iteration=7
# new_angles=[0.7050187]
# likelihood is -870.3268921013266 on iteration 7.
# Iteration=8
# new_angles=[0.70337627]
# likelihood is -870.3148412970602 on iteration 8.
# Iteration=9
# new_angles=[0.7020965]
# likelihood is -870.3024838747942 on iteration 9.
# Iteration=10
# new_angles=[0.70099366]
# likelihood is -870.289685649947 on iteration 10.
# Iteration=11
# new_angles=[0.7001275]
# likelihood is -870.2763726530397 on iteration 11.
# Iteration=12
# new_angles=[0.6994349]
# likelihood is -870.2624123871137 on iteration 12.
# Iteration=13
# new_angles=[0.69888873]
# likelihood is -870.2476624034609 on iteration 13.
# Iteration=14
# new_angles=[0.69842626]
# likelihood is -870.2319480904105 on iteration 14.
# Iteration=15
# new_angles=[0.69805329]
# likelihood is -870.2150780164294 on iteration 15.
# Iteration=16
# new_angles=[0.69773784]
# likelihood is -870.1968113005124 on iteration 16.
# Iteration=17
# new_angles=[0.69742247]
# likelihood is -870.1768503903899 on iteration 17.
# Iteration=18
# new_angles=[0.69719564]
# likelihood is -870.1548451714614 on iteration 18.
# Iteration=19
# new_angles=[0.6970522]
# likelihood is -870.1303315235737 on iteration 19.
# Iteration=20
# new_angles=[0.69690985]
# likelihood is -870.1027055776652 on iteration 20.
# 7-th start
# theta=[0.83118872],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011267950915
# Iteration=1
# new_angles=[0.83118872]
# likelihood is -870.4010540722261 on iteration 1.
# Likelihood is converged!
# 8-th start
# theta=[0.85933204],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011268744408
# Iteration=1
# new_angles=[0.85933204]
# likelihood is -870.4012169695714 on iteration 1.
# Likelihood is converged!
# 9-th start
# theta=[0.73719288],P=[[7.93250092e-08-4.63221143e-24j]]
# Inital likelihood = -870.4011217367256
# Iteration=1
# new_angles=[0.74381132]
# likelihood is -870.3957676578586 on iteration 1.
# Iteration=2
# new_angles=[0.7341905]
# likelihood is -870.3872691664222 on iteration 2.
# Iteration=3
# new_angles=[0.72641955]
# likelihood is -870.3767108349228 on iteration 3.
# Iteration=4
# new_angles=[0.72040993]
# likelihood is -870.3651835534287 on iteration 4.
# Iteration=5
# new_angles=[0.71550632]
# likelihood is -870.3531226295643 on iteration 5.
# Iteration=6
# new_angles=[0.711724]
# likelihood is -870.34094261485 on iteration 6.
# Iteration=7
# new_angles=[0.7087712]
# likelihood is -870.3286755815394 on iteration 7.
# Iteration=8
# new_angles=[0.70637873]
# likelihood is -870.3162352881604 on iteration 8.
# Iteration=9
# new_angles=[0.70444723]
# likelihood is -870.3035560262235 on iteration 9.
# Iteration=10
# new_angles=[0.7028056]
# likelihood is -870.2905018889396 on iteration 10.
# Iteration=11
# new_angles=[0.70152965]
# likelihood is -870.2770152540205 on iteration 11.
# Iteration=12
# new_angles=[0.70057118]
# likelihood is -870.2629544715636 on iteration 12.
# Iteration=13
# new_angles=[0.69978887]
# likelihood is -870.2481302346057 on iteration 13.
# Iteration=14
# new_angles=[0.69914331]
# likelihood is -870.2323688047306 on iteration 14.
# Iteration=15
# new_angles=[0.69859728]
# likelihood is -870.215466424746 on iteration 15.
# Iteration=16
# new_angles=[0.6981952]
# likelihood is -870.1971965086805 on iteration 16.
# Iteration=17
# new_angles=[0.69786909]
# likelihood is -870.1772518362741 on iteration 17.
# Iteration=18
# new_angles=[0.69763129]
# likelihood is -870.155271474441 on iteration 18.
# Iteration=19
# new_angles=[0.69739353]
# likelihood is -870.130780386349 on iteration 19.
# Iteration=20
# new_angles=[0.69725007]
# likelihood is -870.1032008147251 on iteration 20.
# best_start=5
# Время выполнения функции: 26.961973 секунд

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69625779]), array([[0.00285811+0.j]]))

# %%
lf.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q1), lf.incomplete_lkhd(X1_with_mv, theta1_rad, P1, Q1)
# Out:
# (np.float64(-870.1019903949427), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11

failing_sensors2 = np.arange(8)
gap_ratio2 = 0.5 * np.ones_like(failing_sensors2, dtype=np.float32)

theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sn.gss(Num_emitters2, sample_size2, P2)
N2 = sn.gss(Num_sensors2, sample_size2, Q2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sn.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sn.initial_Cov(X2_with_mv)
MUSIC_theta2 = sm.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sn.SNR(A2, P2, Q2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2, lhd_list2, angles_list2 = em.multistart_EM(X2_with_mv, 
                                                                        Num_emitters2, 
                                                                        Q=Q2,
                                                                        theta_guess=MUSIC_theta2, 
                                                                        num_of_starts=20, 
                                                                        max_iter=20, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.72431164],P=[[7.5917774e-08+4.13590306e-24j]]
# Inital likelihood = -689.5792611594288
# Iteration=1
# new_angles=[0.73085337]
# likelihood is -689.5705598066879 on iteration 1.
# Iteration=2
# new_angles=[0.72561956]
# likelihood is -689.5602667131295 on iteration 2.
# Iteration=3
# new_angles=[0.72105983]
# likelihood is -689.5488792227115 on iteration 3.
# Iteration=4
# new_angles=[0.71740529]
# likelihood is -689.5369149472804 on iteration 4.
# Iteration=5
# new_angles=[0.71440852]
# likelihood is -689.5245578771886 on iteration 5.
# Iteration=6
# new_angles=[0.71191892]
# likelihood is -689.511869815612 on iteration 6.
# Iteration=7
# new_angles=[0.70997824]
# likelihood is -689.4988992030724 on iteration 7.
# Iteration=8
# new_angles=[0.70832885]
# likelihood is -689.4854945862774 on iteration 8.
# Iteration=9
# new_angles=[0.70698903]
# likelihood is -689.4715801109759 on iteration 9.
# Iteration=10
# new_angles=[0.70597152]
# likelihood is -689.4570343918355 on iteration 10.
# Iteration=11
# new_angles=[0.70510169]
# likelihood is -689.4416287356771 on iteration 11.
# Iteration=12
# new_angles=[0.70440617]
# likelihood is -689.4251726769829 on iteration 12.
# Iteration=13
# new_angles=[0.70376876]
# likelihood is -689.4073777135334 on iteration 13.
# Iteration=14
# new_angles=[0.70328736]
# likelihood is -689.3879599464009 on iteration 14.
# Iteration=15
# new_angles=[0.70291286]
# likelihood is -689.3665014741416 on iteration 15.
# Iteration=16
# new_angles=[0.70253847]
# likelihood is -689.3424543882256 on iteration 16.
# Iteration=17
# new_angles=[0.70222183]
# likelihood is -689.3151490750812 on iteration 17.
# Iteration=18
# new_angles=[0.70200769]
# likelihood is -689.2836706168176 on iteration 18.
# Iteration=19
# new_angles=[0.70180718]
# likelihood is -689.2467251689222 on iteration 19.
# Iteration=20
# new_angles=[0.70168799]
# likelihood is -689.202523068812 on iteration 20.
# 1-th start
# theta=[0.76634416],P=[[4.65993421e-08-2.64697796e-24j]]
# Inital likelihood = -689.5792672995802
# Iteration=1
# new_angles=[0.76634416]
# likelihood is -689.5766974843754 on iteration 1.
# Iteration=2
# new_angles=[0.75565258]
# likelihood is -689.5707283185983 on iteration 2.
# Iteration=3
# new_angles=[0.74592661]
# likelihood is -689.5612290645921 on iteration 3.
# Iteration=4
# new_angles=[0.73760602]
# likelihood is -689.5490951272161 on iteration 4.
# Iteration=5
# new_angles=[0.73102031]
# likelihood is -689.5356930151044 on iteration 5.
# Iteration=6
# new_angles=[0.72541788]
# likelihood is -689.521360965871 on iteration 6.
# Iteration=7
# new_angles=[0.72095248]
# likelihood is -689.5067803193169 on iteration 7.
# Iteration=8
# new_angles=[0.71734176]
# likelihood is -689.4919946820746 on iteration 8.
# Iteration=9
# new_angles=[0.7143885]
# likelihood is -689.476922985753 on iteration 9.
# Iteration=10
# new_angles=[0.71196186]
# likelihood is -689.4614223718438 on iteration 10.
# Iteration=11
# new_angles=[0.7100211]
# likelihood is -689.4453399876288 on iteration 11.
# Iteration=12
# new_angles=[0.70841575]
# likelihood is -689.4283768370558 on iteration 12.
# Iteration=13
# new_angles=[0.70707583]
# likelihood is -689.4102421704608 on iteration 13.
# Iteration=14
# new_angles=[0.70605824]
# likelihood is -689.390656012698 on iteration 14.
# Iteration=15
# new_angles=[0.70518835]
# likelihood is -689.3691113774421 on iteration 15.
# Iteration=16
# new_angles=[0.70449278]
# likelihood is -689.3451104475932 on iteration 16.
# Iteration=17
# new_angles=[0.70385532]
# likelihood is -689.3179188301608 on iteration 17.
# Iteration=18
# new_angles=[0.70330711]
# likelihood is -689.2866482023976 on iteration 18.
# Iteration=19
# new_angles=[0.7029326]
# likelihood is -689.2500864168808 on iteration 19.
# Iteration=20
# new_angles=[0.70257197]
# likelihood is -689.2064046253047 on iteration 20.
# 2-th start
# theta=[0.7614843],P=[[5.77524969e-08+5.29395592e-24j]]
# Inital likelihood = -689.5792665882861
# Iteration=1
# new_angles=[0.7614843]
# likelihood is -689.5759549441811 on iteration 1.
# Iteration=2
# new_angles=[0.75084161]
# likelihood is -689.569026090025 on iteration 2.
# Iteration=3
# new_angles=[0.74162717]
# likelihood is -689.5588541793137 on iteration 3.
# Iteration=4
# new_angles=[0.73398231]
# likelihood is -689.5465264752529 on iteration 4.
# Iteration=5
# new_angles=[0.72771094]
# likelihood is -689.5330057553616 on iteration 5.
# Iteration=6
# new_angles=[0.72277579]
# likelihood is -689.5190592494637 on iteration 6.
# Iteration=7
# new_angles=[0.7188761]
# likelihood is -689.5049051156003 on iteration 7.
# Iteration=8
# new_angles=[0.71562894]
# likelihood is -689.4904285222968 on iteration 8.
# Iteration=9
# new_angles=[0.7129889]
# likelihood is -689.4756345467553 on iteration 9.
# Iteration=10
# new_angles=[0.71069081]
# likelihood is -689.4602674883636 on iteration 10.
# Iteration=11
# new_angles=[0.70902657]
# likelihood is -689.4444016328163 on iteration 11.
# Iteration=12
# new_angles=[0.70765667]
# likelihood is -689.4276037882005 on iteration 12.
# Iteration=13
# new_angles=[0.70646459]
# likelihood is -689.4095594047964 on iteration 13.
# Iteration=14
# new_angles=[0.70550211]
# likelihood is -689.3899889791868 on iteration 14.
# Iteration=15
# new_angles=[0.70463263]
# likelihood is -689.3684215023139 on iteration 15.
# Iteration=16
# new_angles=[0.70399509]
# likelihood is -689.3444090940535 on iteration 16.
# Iteration=17
# new_angles=[0.70344682]
# likelihood is -689.3172038986559 on iteration 17.
# Iteration=18
# new_angles=[0.70296731]
# likelihood is -689.2858876016928 on iteration 18.
# Iteration=19
# new_angles=[0.70260668]
# likelihood is -689.2492250910859 on iteration 19.
# Iteration=20
# new_angles=[0.70229001]
# likelihood is -689.205417085878 on iteration 20.
# 3-th start
# theta=[0.83255839],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688437123
# Iteration=1
# new_angles=[0.83255839]
# likelihood is -689.5799860537165 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 4-th start
# theta=[0.73004403],P=[[6.95706666e-08-3.30872245e-25j]]
# Inital likelihood = -689.5792623721018
# Iteration=1
# new_angles=[0.73661954]
# likelihood is -689.5715479752268 on iteration 1.
# Iteration=2
# new_angles=[0.73005059]
# likelihood is -689.5616294636351 on iteration 2.
# Iteration=3
# new_angles=[0.7248205]
# likelihood is -689.5503959615158 on iteration 3.
# Iteration=4
# new_angles=[0.72053355]
# likelihood is -689.5383672276848 on iteration 4.
# Iteration=5
# new_angles=[0.71691021]
# likelihood is -689.5258006410373 on iteration 5.
# Iteration=6
# new_angles=[0.71395806]
# likelihood is -689.5129088302516 on iteration 6.
# Iteration=7
# new_angles=[0.71164418]
# likelihood is -689.4997575350544 on iteration 7.
# Iteration=8
# new_angles=[0.70971468]
# likelihood is -689.4862056828267 on iteration 8.
# Iteration=9
# new_angles=[0.70810974]
# likelihood is -689.4721548922478 on iteration 9.
# Iteration=10
# new_angles=[0.70682802]
# likelihood is -689.4574879003497 on iteration 10.
# Iteration=11
# new_angles=[0.70581066]
# likelihood is -689.442018174215 on iteration 11.
# Iteration=12
# new_angles=[0.70488891]
# likelihood is -689.4254772440464 on iteration 12.
# Iteration=13
# new_angles=[0.70419351]
# likelihood is -689.4076659372614 on iteration 13.
# Iteration=14
# new_angles=[0.70364515]
# likelihood is -689.3882366901989 on iteration 14.
# Iteration=15
# new_angles=[0.70309704]
# likelihood is -689.3667419932709 on iteration 15.
# Iteration=16
# new_angles=[0.70272259]
# likelihood is -689.3427153479149 on iteration 16.
# Iteration=17
# new_angles=[0.70236203]
# likelihood is -689.3154258159465 on iteration 17.
# Iteration=18
# new_angles=[0.70213425]
# likelihood is -689.2839811299478 on iteration 18.
# Iteration=19
# new_angles=[0.70190651]
# likelihood is -689.2470779220299 on iteration 19.
# Iteration=20
# new_angles=[0.70168799]
# likelihood is -689.202920582578 on iteration 20.
# 5-th start
# theta=[0.7029336],P=[[1.77615171e-07-2.64697796e-24j]]
# Inital likelihood = -689.579248242526
# Iteration=1
# new_angles=[0.70629949]
# likelihood is -689.567760694715 on iteration 1.
# Iteration=2
# new_angles=[0.70528258]
# likelihood is -689.5563628155174 on iteration 2.
# Iteration=3
# new_angles=[0.70426655]
# likelihood is -689.5448407281609 on iteration 3.
# Iteration=4
# new_angles=[0.70362601]
# likelihood is -689.5331790387729 on iteration 4.
# Iteration=5
# new_angles=[0.70307791]
# likelihood is -689.5213011997688 on iteration 5.
# Iteration=6
# new_angles=[0.70270347]
# likelihood is -689.5091418842253 on iteration 6.
# Iteration=7
# new_angles=[0.70234291]
# likelihood is -689.4966033429354 on iteration 7.
# Iteration=8
# new_angles=[0.70198246]
# likelihood is -689.4835852755278 on iteration 8.
# Iteration=9
# new_angles=[0.70175475]
# likelihood is -689.4699795054811 on iteration 9.
# Iteration=10
# new_angles=[0.70152709]
# likelihood is -689.4556371053404 on iteration 10.
# Iteration=11
# new_angles=[0.70136837]
# likelihood is -689.4403940600826 on iteration 11.
# Iteration=12
# new_angles=[0.70131399]
# likelihood is -689.4240467076232 on iteration 12.
# Iteration=13
# new_angles=[0.70125961]
# likelihood is -689.4063370947746 on iteration 13.
# Iteration=14
# new_angles=[0.70121898]
# likelihood is -689.3869491143673 on iteration 14.
# Iteration=15
# new_angles=[0.70117835]
# likelihood is -689.3654784888732 on iteration 15.
# Iteration=16
# new_angles=[0.70113773]
# likelihood is -689.3414020470581 on iteration 16.
# Iteration=17
# new_angles=[0.7010971]
# likelihood is -689.3140287713733 on iteration 17.
# Iteration=18
# new_angles=[0.70104273]
# likelihood is -689.2824261113797 on iteration 18.
# Iteration=19
# new_angles=[0.70100211]
# likelihood is -689.2453091249866 on iteration 19.
# Iteration=20
# new_angles=[0.70094774]
# likelihood is -689.2008537190571 on iteration 20.
# 6-th start
# theta=[0.73079862],P=[[6.86735671e-08-2.97785021e-24j]]
# Inital likelihood = -689.5792625347437
# Iteration=1
# new_angles=[0.73737862]
# likelihood is -689.5716832163106 on iteration 1.
# Iteration=2
# new_angles=[0.73043241]
# likelihood is -689.5617534432965 on iteration 2.
# Iteration=3
# new_angles=[0.7248329]
# likelihood is -689.5504025214432 on iteration 3.
# Iteration=4
# new_angles=[0.7205459]
# likelihood is -689.5383746902019 on iteration 4.
# Iteration=5
# new_angles=[0.71692253]
# likelihood is -689.5258085782089 on iteration 5.
# Iteration=6
# new_angles=[0.71397035]
# likelihood is -689.5129169546884 on iteration 6.
# Iteration=7
# new_angles=[0.71165644]
# likelihood is -689.4997657106429 on iteration 7.
# Iteration=8
# new_angles=[0.70972692]
# likelihood is -689.4862137838822 on iteration 8.
# Iteration=9
# new_angles=[0.70812197]
# likelihood is -689.4721628509395 on iteration 9.
# Iteration=10
# new_angles=[0.70684023]
# likelihood is -689.4574957374994 on iteration 10.
# Iteration=11
# new_angles=[0.70582285]
# likelihood is -689.4420259497729 on iteration 11.
# Iteration=12
# new_angles=[0.70488891]
# likelihood is -689.4254803235323 on iteration 12.
# Iteration=13
# new_angles=[0.70419351]
# likelihood is -689.4076692710063 on iteration 13.
# Iteration=14
# new_angles=[0.70364515]
# likelihood is -689.3882403339975 on iteration 14.
# Iteration=15
# new_angles=[0.70309704]
# likelihood is -689.3667460197266 on iteration 15.
# Iteration=16
# new_angles=[0.70272259]
# likelihood is -689.3427198505827 on iteration 16.
# Iteration=17
# new_angles=[0.70236203]
# likelihood is -689.3154309201494 on iteration 17.
# Iteration=18
# new_angles=[0.70213425]
# likelihood is -689.2839870050552 on iteration 18.
# Iteration=19
# new_angles=[0.70190651]
# likelihood is -689.2470848041855 on iteration 19.
# Iteration=20
# new_angles=[0.70168799]
# likelihood is -689.2029288090523 on iteration 20.
# 7-th start
# theta=[0.83991537],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579268841746
# Iteration=1
# new_angles=[0.83991537]
# likelihood is -689.5799820597101 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 8-th start
# theta=[0.86805869],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688779773
# Iteration=1
# new_angles=[0.86805869]
# likelihood is -689.5800566091303 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 9-th start
# theta=[0.74591953],P=[[4.89913064e-08-9.92616735e-25j]]
# Inital likelihood = -689.5792655524413
# Iteration=1
# new_angles=[0.74591953]
# likelihood is -689.5732483882189 on iteration 1.
# Iteration=2
# new_angles=[0.73759899]
# likelihood is -689.5642182204988 on iteration 2.
# Iteration=3
# new_angles=[0.73065141]
# likelihood is -689.5530958981615 on iteration 3.
# Iteration=4
# new_angles=[0.72505081]
# likelihood is -689.5408167590726 on iteration 4.
# Iteration=5
# new_angles=[0.72049661]
# likelihood is -689.5279026582102 on iteration 5.
# Iteration=6
# new_angles=[0.7168734]
# likelihood is -689.5146772541428 on iteration 6.
# Iteration=7
# new_angles=[0.71392134]
# likelihood is -689.5011617474566 on iteration 7.
# Iteration=8
# new_angles=[0.71160753]
# likelihood is -689.4873778114173 on iteration 8.
# Iteration=9
# new_angles=[0.70970672]
# likelihood is -689.4731441714364 on iteration 9.
# Iteration=10
# new_angles=[0.70810179]
# likelihood is -689.4582931724966 on iteration 10.
# Iteration=11
# new_angles=[0.70682008]
# likelihood is -689.4426890995624 on iteration 11.
# Iteration=12
# new_angles=[0.70580272]
# likelihood is -689.4261009192618 on iteration 12.
# Iteration=13
# new_angles=[0.70488891]
# likelihood is -689.4082057147108 on iteration 13.
# Iteration=14
# new_angles=[0.70419351]
# likelihood is -689.3887388356956 on iteration 14.
# Iteration=15
# new_angles=[0.70364515]
# likelihood is -689.3672669962202 on iteration 15.
# Iteration=16
# new_angles=[0.70309704]
# likelihood is -689.3432207663399 on iteration 16.
# Iteration=17
# new_angles=[0.70272259]
# likelihood is -689.31597601819 on iteration 17.
# Iteration=18
# new_angles=[0.70236203]
# likelihood is -689.2845630061424 on iteration 18.
# Iteration=19
# new_angles=[0.70213425]
# likelihood is -689.2477495748069 on iteration 19.
# Iteration=20
# new_angles=[0.70190651]
# likelihood is -689.2037096677643 on iteration 20.
# 10-th start
# theta=[0.45944132],P=[[5.55659323e-08+3.57342025e-23j]]
# Inital likelihood = -689.5792678138821
# Iteration=1
# new_angles=[0.45944132]
# likelihood is -689.5780391950967 on iteration 1.
# Iteration=2
# new_angles=[0.46053389]
# likelihood is -689.5767634966759 on iteration 2.
# Iteration=3
# new_angles=[0.46182576]
# likelihood is -689.5754289768214 on iteration 3.
# Iteration=4
# new_angles=[0.4629169]
# likelihood is -689.574062383113 on iteration 4.
# Iteration=5
# new_angles=[0.46400863]
# likelihood is -689.5726579259101 on iteration 5.
# Iteration=6
# new_angles=[0.46510095]
# likelihood is -689.5712183323031 on iteration 6.
# Iteration=7
# new_angles=[0.46588585]
# likelihood is -689.5697740944784 on iteration 7.
# Iteration=8
# new_angles=[0.46658359]
# likelihood is -689.5683067036156 on iteration 8.
# Iteration=9
# new_angles=[0.46720907]
# likelihood is -689.5668126490798 on iteration 9.
# Iteration=10
# new_angles=[0.46774966]
# likelihood is -689.5652895308943 on iteration 10.
# Iteration=11
# new_angles=[0.4682904]
# likelihood is -689.5637232372252 on iteration 11.
# Iteration=12
# new_angles=[0.46871439]
# likelihood is -689.5621192434705 on iteration 12.
# Iteration=13
# new_angles=[0.46913848]
# likelihood is -689.5604568972557 on iteration 13.
# Iteration=14
# new_angles=[0.46948163]
# likelihood is -689.5587348059918 on iteration 14.
# Iteration=15
# new_angles=[0.46990589]
# likelihood is -689.5569234423664 on iteration 15.
# Iteration=16
# new_angles=[0.47026777]
# likelihood is -689.5550239804975 on iteration 16.
# Iteration=17
# new_angles=[0.4705444]
# likelihood is -689.5530216031361 on iteration 17.
# Iteration=18
# new_angles=[0.47078349]
# likelihood is -689.550890635853 on iteration 18.
# Iteration=19
# new_angles=[0.47098586]
# likelihood is -689.5486060862494 on iteration 19.
# Iteration=20
# new_angles=[0.47118825]
# likelihood is -689.5461335101254 on iteration 20.
# 11-th start
# theta=[0.49094045],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579267869759
# Iteration=1
# new_angles=[0.49094045]
# likelihood is -689.5779844416243 on iteration 1.
# Iteration=2
# new_angles=[0.49008754]
# likelihood is -689.5766884490816 on iteration 2.
# Iteration=3
# new_angles=[0.48977567]
# likelihood is -689.5753911619398 on iteration 3.
# Iteration=4
# new_angles=[0.48898102]
# likelihood is -689.5740637153062 on iteration 4.
# Iteration=5
# new_angles=[0.488428]
# likelihood is -689.5727267236493 on iteration 5.
# Iteration=6
# new_angles=[0.48787515]
# likelihood is -689.5713691683337 on iteration 6.
# Iteration=7
# new_angles=[0.48732246]
# likelihood is -689.5699872900657 on iteration 7.
# Iteration=8
# new_angles=[0.48676993]
# likelihood is -689.5685767458536 on iteration 8.
# Iteration=9
# new_angles=[0.48621756]
# likelihood is -689.5671325352454 on iteration 9.
# Iteration=10
# new_angles=[0.48566535]
# likelihood is -689.5656489059073 on iteration 10.
# Iteration=11
# new_angles=[0.48511607]
# likelihood is -689.5641195415187 on iteration 11.
# Iteration=12
# new_angles=[0.48456694]
# likelihood is -689.5625365310666 on iteration 12.
# Iteration=13
# new_angles=[0.48409459]
# likelihood is -689.5609007624706 on iteration 13.
# Iteration=14
# new_angles=[0.48362235]
# likelihood is -689.5591932783238 on iteration 14.
# Iteration=15
# new_angles=[0.48315023]
# likelihood is -689.5574018433259 on iteration 15.
# Iteration=16
# new_angles=[0.48267823]
# likelihood is -689.5555120325387 on iteration 16.
# Iteration=17
# new_angles=[0.48235548]
# likelihood is -689.5535299763797 on iteration 17.
# Iteration=18
# new_angles=[0.48204488]
# likelihood is -689.5514159869058 on iteration 18.
# Iteration=19
# new_angles=[0.48173433]
# likelihood is -689.5491433573719 on iteration 19.
# Iteration=20
# new_angles=[0.48142383]
# likelihood is -689.5466817168848 on iteration 20.
# 12-th start
# theta=[0.61180126],P=[[8.06311518e-08-5.29395592e-24j]]
# Inital likelihood = -689.5792664814606
# Iteration=1
# new_angles=[0.61180126]
# likelihood is -689.5767554508247 on iteration 1.
# Iteration=2
# new_angles=[0.61164957]
# likelihood is -689.5742599241597 on iteration 2.
# Iteration=3
# new_angles=[0.61164957]
# likelihood is -689.571761203219 on iteration 3.
# Iteration=4
# new_angles=[0.61164957]
# likelihood is -689.5692533518511 on iteration 4.
# Iteration=5
# new_angles=[0.61142701]
# likelihood is -689.5667260155157 on iteration 5.
# Iteration=6
# new_angles=[0.61129271]
# likelihood is -689.5641755442987 on iteration 6.
# Iteration=7
# new_angles=[0.61115842]
# likelihood is -689.5615920569674 on iteration 7.
# Iteration=8
# new_angles=[0.61093594]
# likelihood is -689.558961906709 on iteration 8.
# Iteration=9
# new_angles=[0.61071349]
# likelihood is -689.556275617835 on iteration 9.
# Iteration=10
# new_angles=[0.61057925]
# likelihood is -689.553525721281 on iteration 10.
# Iteration=11
# new_angles=[0.61024342]
# likelihood is -689.5506773725014 on iteration 11.
# Iteration=12
# new_angles=[0.60994852]
# likelihood is -689.5477269551379 on iteration 12.
# Iteration=13
# new_angles=[0.60964376]
# likelihood is -689.5446498020204 on iteration 13.
# Iteration=14
# new_angles=[0.60930815]
# likelihood is -689.541417892542 on iteration 14.
# Iteration=15
# new_angles=[0.60897262]
# likelihood is -689.5380055414337 on iteration 15.
# Iteration=16
# new_angles=[0.60863717]
# likelihood is -689.5343786221329 on iteration 16.
# Iteration=17
# new_angles=[0.60826188]
# likelihood is -689.5304867165488 on iteration 17.
# Iteration=18
# new_angles=[0.60777816]
# likelihood is -689.5262561765594 on iteration 18.
# Iteration=19
# new_angles=[0.60726903]
# likelihood is -689.5216377793496 on iteration 19.
# Iteration=20
# new_angles=[0.60674993]
# likelihood is -689.5165558857061 on iteration 20.
# 13-th start
# theta=[0.74517223],P=[[4.99996792e-08+3.97046694e-24j]]
# Inital likelihood = -689.5792654235444
# Iteration=1
# new_angles=[0.74517223]
# likelihood is -689.5731108491135 on iteration 1.
# Iteration=2
# new_angles=[0.73685736]
# likelihood is -689.5639542150687 on iteration 2.
# Iteration=3
# new_angles=[0.73028372]
# likelihood is -689.5529152906847 on iteration 3.
# Iteration=4
# new_angles=[0.72468495]
# likelihood is -689.5406055055576 on iteration 4.
# Iteration=5
# new_angles=[0.72039851]
# likelihood is -689.5278377636319 on iteration 5.
# Iteration=6
# new_angles=[0.71678954]
# likelihood is -689.5146192212236 on iteration 6.
# Iteration=7
# new_angles=[0.7138377]
# likelihood is -689.5011038153938 on iteration 7.
# Iteration=8
# new_angles=[0.71134933]
# likelihood is -689.4872181670919 on iteration 8.
# Iteration=9
# new_angles=[0.7095097]
# likelihood is -689.4730232369485 on iteration 9.
# Iteration=10
# new_angles=[0.70809857]
# likelihood is -689.4582780485597 on iteration 10.
# Iteration=11
# new_angles=[0.70681687]
# likelihood is -689.4426731613213 on iteration 11.
# Iteration=12
# new_angles=[0.70581331]
# likelihood is -689.4260903166426 on iteration 12.
# Iteration=13
# new_angles=[0.70488891]
# likelihood is -689.4081890977212 on iteration 13.
# Iteration=14
# new_angles=[0.70419351]
# likelihood is -689.3887206675329 on iteration 14.
# Iteration=15
# new_angles=[0.70364515]
# likelihood is -689.3672469207368 on iteration 15.
# Iteration=16
# new_angles=[0.70309704]
# likelihood is -689.3431983131969 on iteration 16.
# Iteration=17
# new_angles=[0.70272259]
# likelihood is -689.3159505686588 on iteration 17.
# Iteration=18
# new_angles=[0.70236203]
# likelihood is -689.2845337148258 on iteration 18.
# Iteration=19
# new_angles=[0.70213425]
# likelihood is -689.2477152707252 on iteration 19.
# Iteration=20
# new_angles=[0.70190651]
# likelihood is -689.203668673908 on iteration 20.
# 14-th start
# theta=[0.81529611],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688264825
# Iteration=1
# new_angles=[0.81529611]
# likelihood is -689.5799505326396 on iteration 1.
# Likelihood is converged!
# 15-th start
# theta=[0.64780331],P=[[8.03558405e-08+0.j]]
# Inital likelihood = -689.5792644427597
# Iteration=1
# new_angles=[0.64780331]
# likelihood is -689.5742025204198 on iteration 1.
# Iteration=2
# new_angles=[0.6527111]
# likelihood is -689.5676704684614 on iteration 2.
# Iteration=3
# new_angles=[0.65772616]
# likelihood is -689.5594244062034 on iteration 3.
# Iteration=4
# new_angles=[0.66267469]
# likelihood is -689.5494391748612 on iteration 4.
# Iteration=5
# new_angles=[0.6676393]
# likelihood is -689.5376923486862 on iteration 5.
# Iteration=6
# new_angles=[0.67200245]
# likelihood is -689.524858882185 on iteration 6.
# Iteration=7
# new_angles=[0.67601138]
# likelihood is -689.5110083289983 on iteration 7.
# Iteration=8
# new_angles=[0.67977271]
# likelihood is -689.4962209690949 on iteration 8.
# Iteration=9
# new_angles=[0.68291906]
# likelihood is -689.4810020052474 on iteration 9.
# Iteration=10
# new_angles=[0.68570115]
# likelihood is -689.4651348716607 on iteration 10.
# Iteration=11
# new_angles=[0.68800215]
# likelihood is -689.4486841496793 on iteration 11.
# Iteration=12
# new_angles=[0.68999092]
# likelihood is -689.4313435002613 on iteration 12.
# Iteration=13
# new_angles=[0.69166593]
# likelihood is -689.4129026336282 on iteration 13.
# Iteration=14
# new_angles=[0.69308834]
# likelihood is -689.3930131170141 on iteration 14.
# Iteration=15
# new_angles=[0.69430441]
# likelihood is -689.3712508335154 on iteration 15.
# Iteration=16
# new_angles=[0.69531195]
# likelihood is -689.3471120833848 on iteration 16.
# Iteration=17
# new_angles=[0.69621203]
# likelihood is -689.3198543142944 on iteration 17.
# Iteration=18
# new_angles=[0.6969402]
# likelihood is -689.2886270229484 on iteration 18.
# Iteration=19
# new_angles=[0.69757714]
# likelihood is -689.2521426249152 on iteration 19.
# Iteration=20
# new_angles=[0.69816018]
# likelihood is -689.2086418584479 on iteration 20.
# 16-th start
# theta=[0.22711654],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792687212914
# Iteration=1
# new_angles=[0.22711654]
# likelihood is -689.5797343615066 on iteration 1.
# Likelihood is converged!
# 17-th start
# theta=[0.45039062],P=[[4.93435618e-08-4.76456033e-23j]]
# Inital likelihood = -689.579268038814
# Iteration=1
# new_angles=[0.45039062]
# likelihood is -689.5783423877429 on iteration 1.
# Iteration=2
# new_angles=[0.45271134]
# likelihood is -689.577238595182 on iteration 2.
# Iteration=3
# new_angles=[0.45488441]
# likelihood is -689.5759955730678 on iteration 3.
# Iteration=4
# new_angles=[0.45650938]
# likelihood is -689.5746963782655 on iteration 4.
# Iteration=5
# new_angles=[0.45825388]
# likelihood is -689.5732958322088 on iteration 5.
# Iteration=6
# new_angles=[0.45954429]
# likelihood is -689.5718863192649 on iteration 6.
# Iteration=7
# new_angles=[0.46078489]
# likelihood is -689.5704259941815 on iteration 7.
# Iteration=8
# new_angles=[0.46195394]
# likelihood is -689.5689233144384 on iteration 8.
# Iteration=9
# new_angles=[0.46292223]
# likelihood is -689.5674032689797 on iteration 9.
# Iteration=10
# new_angles=[0.46370627]
# likelihood is -689.5658648705735 on iteration 10.
# Iteration=11
# new_angles=[0.46449061]
# likelihood is -689.5642736444249 on iteration 11.
# Iteration=12
# new_angles=[0.46523861]
# likelihood is -689.56263095135 on iteration 12.
# Iteration=13
# new_angles=[0.4658907]
# likelihood is -689.5609409704595 on iteration 13.
# Iteration=14
# new_angles=[0.46644004]
# likelihood is -689.5591964326777 on iteration 14.
# Iteration=15
# new_angles=[0.46698953]
# likelihood is -689.557367404624 on iteration 15.
# Iteration=16
# new_angles=[0.46753006]
# likelihood is -689.5554419373191 on iteration 16.
# Iteration=17
# new_angles=[0.46807074]
# likelihood is -689.5534019251099 on iteration 17.
# Iteration=18
# new_angles=[0.46849469]
# likelihood is -689.5512487384069 on iteration 18.
# Iteration=19
# new_angles=[0.46903563]
# likelihood is -689.5489153375502 on iteration 19.
# Iteration=20
# new_angles=[0.46937876]
# likelihood is -689.5464283964934 on iteration 20.
# 18-th start
# theta=[1.57079633],P=[[8.75235434e-08-2.70617725e-23j]]
# Inital likelihood = -689.5792674589636
# Iteration=1
# new_angles=[1.57079633]
# likelihood is -689.5780764683271 on iteration 1.
# Iteration=2
# new_angles=[1.48237918]
# likelihood is -689.5762604406547 on iteration 2.
# Iteration=3
# new_angles=[1.4457148]
# likelihood is -689.5738907777152 on iteration 3.
# Iteration=4
# new_angles=[1.4309281]
# likelihood is -689.5715643098971 on iteration 4.
# Iteration=5
# new_angles=[1.41755332]
# likelihood is -689.5690042369225 on iteration 5.
# Iteration=6
# new_angles=[1.40524789]
# likelihood is -689.5662318149793 on iteration 6.
# Iteration=7
# new_angles=[1.39378864]
# likelihood is -689.5632676280786 on iteration 7.
# Iteration=8
# new_angles=[1.3833973]
# likelihood is -689.5601572430886 on iteration 8.
# Iteration=9
# new_angles=[1.37569116]
# likelihood is -689.5570512564183 on iteration 9.
# Iteration=10
# new_angles=[1.36862403]
# likelihood is -689.5538303448354 on iteration 10.
# Iteration=11
# new_angles=[1.36313435]
# likelihood is -689.5505759776671 on iteration 11.
# Iteration=12
# new_angles=[1.35844978]
# likelihood is -689.5472291866208 on iteration 12.
# Iteration=13
# new_angles=[1.35386487]
# likelihood is -689.5437199702486 on iteration 13.
# Iteration=14
# new_angles=[1.34969353]
# likelihood is -689.5400574228995 on iteration 14.
# Iteration=15
# new_angles=[1.34606276]
# likelihood is -689.5362301924538 on iteration 15.
# Iteration=16
# new_angles=[1.34279939]
# likelihood is -689.5321928972642 on iteration 16.
# Iteration=17
# new_angles=[1.33988805]
# likelihood is -689.5279056193737 on iteration 17.
# Iteration=18
# new_angles=[1.33701233]
# likelihood is -689.5232902123469 on iteration 18.
# Iteration=19
# new_angles=[1.33431334]
# likelihood is -689.518298353551 on iteration 19.
# Iteration=20
# new_angles=[1.33223814]
# likelihood is -689.512895180598 on iteration 20.
# 19-th start
# theta=[0.75399535],P=[[7.64820505e-08-1.0753348e-24j]]
# Inital likelihood = -689.5792650119403
# Iteration=1
# new_angles=[0.75399535]
# likelihood is -689.5746855128481 on iteration 1.
# Iteration=2
# new_angles=[0.74428431]
# likelihood is -689.5666191815061 on iteration 2.
# Iteration=3
# new_angles=[0.73634751]
# likelihood is -689.5559778014723 on iteration 3.
# Iteration=4
# new_angles=[0.72978016]
# likelihood is -689.5436828860471 on iteration 4.
# Iteration=5
# new_angles=[0.72455133]
# likelihood is -689.5305968994433 on iteration 5.
# Iteration=6
# new_angles=[0.72027937]
# likelihood is -689.5170332240776 on iteration 6.
# Iteration=7
# new_angles=[0.71667077]
# likelihood is -689.5030749973645 on iteration 7.
# Iteration=8
# new_angles=[0.71371923]
# likelihood is -689.4888403825939 on iteration 8.
# Iteration=9
# new_angles=[0.71141969]
# likelihood is -689.4743217458283 on iteration 9.
# Iteration=10
# new_angles=[0.70957995]
# likelihood is -689.4592981601317 on iteration 10.
# Iteration=11
# new_angles=[0.70809857]
# likelihood is -689.443559324445 on iteration 11.
# Iteration=12
# new_angles=[0.70681687]
# likelihood is -689.4268189266098 on iteration 12.
# Iteration=13
# new_angles=[0.70577027]
# likelihood is -689.4088523241929 on iteration 13.
# Iteration=14
# new_angles=[0.70488891]
# likelihood is -689.3893088812391 on iteration 14.
# Iteration=15
# new_angles=[0.70419351]
# likelihood is -689.3677966799291 on iteration 15.
# Iteration=16
# new_angles=[0.70364515]
# likelihood is -689.3437780715033 on iteration 16.
# Iteration=17
# new_angles=[0.70309704]
# likelihood is -689.3165150192344 on iteration 17.
# Iteration=18
# new_angles=[0.70272259]
# likelihood is -689.2851568646886 on iteration 18.
# Iteration=19
# new_angles=[0.70236203]
# likelihood is -689.2483862980818 on iteration 19.
# Iteration=20
# new_angles=[0.70213425]
# likelihood is -689.2044586578414 on iteration 20.
# best_start=5
# Время выполнения функции: 48.521225 секунд

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.70094774]), array([[0.00336201+0.j]]))

# %%
lf.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q2), lf.incomplete_lkhd(X2_with_mv, theta2_rad, P2, Q2)
# Out:
# (np.float64(-689.2008537190571), np.float64(-673.6467390084401))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="ticks", context="paper", palette="colorblind")

# %%
from pathlib import Path
import sys

try:
    ROOT = Path().resolve().parents[1]
    assert (ROOT / "common").exists()
except AssertionError:
    ROOT = next(p for p in Path().resolve().parents if (p / "common").exists())

if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
#print(ROOT)

# %%
from common import sensors as sn 
from common import subspace_methods as sm
from common import em_tools as em
from common import log_funcs as lf

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12

failing_sensors1 = np.arange(10)
gap_ratio1 = 0.5 * np.ones_like(failing_sensors1, dtype=np.float32)

theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах

signal_dB = -3
noise_dB = 9

signal_var = sn.db_to_var(signal_dB)
noise_var = sn.db_to_var(noise_dB)

P1 = signal_var * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q1 = noise_var * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов

#P1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
#Q1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов

A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sn.gss(Num_emitters1, sample_size1, P1)
N1 = sn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sn.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sn.initial_Cov(X1_with_mv)
MUSIC_theta1 = sm.MUSIC_DoA(R1, Num_emitters1)
#MUSIC_theta1 = np.array([0.68])

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sn.SNR(A1, P1, Q1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.5773933612004833)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = em.multistart_EM(X1_with_mv, 
                                                                        Num_emitters1, 
                                                                        Q=Q1,
                                                                        theta_guess=MUSIC_theta1, 
                                                                        num_of_starts=1, 
                                                                        max_iter=50, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-5)
# Out:
# 0-th start
# theta=[0.71558499],P=[[9.52396052e-08-9.92616735e-25j]]
# Inital likelihood = -769.0765271449704
# Iteration=1
# new_angles=[0.71558499]
# likelihood is -769.0756521612998 on iteration 1.
# Iteration=2
# new_angles=[0.71171286]
# likelihood is -769.0747048759379 on iteration 2.
# Iteration=3
# new_angles=[0.70922905]
# likelihood is -769.0737377233295 on iteration 3.
# Iteration=4
# new_angles=[0.70675051]
# likelihood is -769.07274747071 on iteration 4.
# Iteration=5
# new_angles=[0.70510566]
# likelihood is -769.0717609425681 on iteration 5.
# Iteration=6
# new_angles=[0.70382722]
# likelihood is -769.0707739697746 on iteration 6.
# Iteration=7
# new_angles=[0.70281244]
# likelihood is -769.0697866564614 on iteration 7.
# Iteration=8
# new_angles=[0.70179854]
# likelihood is -769.0687948273212 on iteration 8.
# Iteration=9
# new_angles=[0.7007855]
# likelihood is -769.0677997127265 on iteration 9.
# Iteration=10
# new_angles=[0.70042553]
# likelihood is -769.0668105802056 on iteration 10.
# Iteration=11
# new_angles=[0.70006566]
# likelihood is -769.0658161774188 on iteration 11.
# Iteration=12
# new_angles=[0.70006566]
# likelihood is -769.0648207728987 on iteration 12.
# Iteration=13
# new_angles=[0.70006566]
# likelihood is -769.0638187844381 on iteration 13.
# Iteration=14
# new_angles=[0.69941995]
# likelihood is -769.0628000340345 on iteration 14.
# Iteration=15
# new_angles=[0.69906039]
# likelihood is -769.0617775895957 on iteration 15.
# Iteration=16
# new_angles=[0.69906039]
# likelihood is -769.0607493785636 on iteration 16.
# Iteration=17
# new_angles=[0.69906039]
# likelihood is -769.0597107108687 on iteration 17.
# Iteration=18
# new_angles=[0.69906039]
# likelihood is -769.05866044906 on iteration 18.
# Iteration=19
# new_angles=[0.69906039]
# likelihood is -769.0575973758542 on iteration 19.
# Iteration=20
# new_angles=[0.69906039]
# likelihood is -769.0565201872918 on iteration 20.
# Iteration=21
# new_angles=[0.69906039]
# likelihood is -769.0554274850197 on iteration 21.
# Iteration=22
# new_angles=[0.69906039]
# likelihood is -769.0543177675839 on iteration 22.
# Iteration=23
# new_angles=[0.69906039]
# likelihood is -769.0531894206013 on iteration 23.
# Iteration=24
# new_angles=[0.69906039]
# likelihood is -769.0520407056476 on iteration 24.
# Iteration=25
# new_angles=[0.69882235]
# likelihood is -769.0508663911611 on iteration 25.
# Iteration=26
# new_angles=[0.69881491]
# likelihood is -769.0496708992374 on iteration 26.
# Iteration=27
# new_angles=[0.69880747]
# likelihood is -769.0484489323812 on iteration 27.
# Iteration=28
# new_angles=[0.69880004]
# likelihood is -769.0471981115495 on iteration 28.
# Iteration=29
# new_angles=[0.6987926]
# likelihood is -769.0459158512531 on iteration 29.
# Iteration=30
# new_angles=[0.69878516]
# likelihood is -769.0445993356113 on iteration 30.
# Iteration=31
# new_angles=[0.69877773]
# likelihood is -769.0432454909323 on iteration 31.
# Iteration=32
# new_angles=[0.69877029]
# likelihood is -769.0418509542317 on iteration 32.
# Iteration=33
# new_angles=[0.69876285]
# likelihood is -769.0404120369825 on iteration 33.
# Iteration=34
# new_angles=[0.69875542]
# likelihood is -769.0389246832489 on iteration 34.
# Iteration=35
# new_angles=[0.69874798]
# likelihood is -769.0373844211749 on iteration 35.
# Iteration=36
# new_angles=[0.69874054]
# likelihood is -769.0357863065801 on iteration 36.
# Iteration=37
# new_angles=[0.69873311]
# likelihood is -769.0341248571439 on iteration 37.
# Iteration=38
# new_angles=[0.69872567]
# likelihood is -769.0323939753026 on iteration 38.
# Iteration=39
# new_angles=[0.69871823]
# likelihood is -769.0305868575655 on iteration 39.
# Iteration=40
# new_angles=[0.6987108]
# likelihood is -769.0286958873899 on iteration 40.
# Iteration=41
# new_angles=[0.69856718]
# likelihood is -769.0267100766613 on iteration 41.
# Iteration=42
# new_angles=[0.69855974]
# likelihood is -769.0246245506823 on iteration 42.
# Iteration=43
# new_angles=[0.69855231]
# likelihood is -769.0224260400673 on iteration 43.
# Iteration=44
# new_angles=[0.69854487]
# likelihood is -769.0201021298458 on iteration 44.
# Iteration=45
# new_angles=[0.69853743]
# likelihood is -769.0176386472248 on iteration 45.
# Iteration=46
# new_angles=[0.69853]
# likelihood is -769.0150193379776 on iteration 46.
# Iteration=47
# new_angles=[0.69844669]
# likelihood is -769.0122241794322 on iteration 47.
# Iteration=48
# new_angles=[0.69840616]
# likelihood is -769.0092334958173 on iteration 48.
# Iteration=49
# new_angles=[0.69836563]
# likelihood is -769.0060212785004 on iteration 49.
# Iteration=50
# new_angles=[0.6983251]
# likelihood is -769.0025578981843 on iteration 50.
# best_start=0
# Время выполнения функции: 9.064088 секунд

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.6983251]), array([[0.00076628+0.j]]))

# %%
lf.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q1), lf.incomplete_lkhd(X1_with_mv, theta1_rad, P1, Q1)
# Out:
# (np.float64(-769.0025578981843), np.float64(-751.4250665632064))

# %%
lhd_list1 = np.array(lhd_list1)
angles_list1 = np.rad2deg(np.array(angles_list1))
x1 = np.arange(len(angles_list1))

# %%
x_grid = np.arange(1,50,5)

# %%
plt.figure(figsize=(6, 3))
plt.title(r'$\text{График сходимости} \,\,\theta_1 \text{ для первого набора начальных условий}$')
plt.plot(x1, angles_list1,color='darkblue', label=r'$\theta_1^{(\tau)}$')
plt.plot(x1, np.tile(theta1_deg, len(angles_list1)), color='green', label=r'Истинное значение $\theta_1$', linestyle='--')
plt.xlabel('Номер итерации') 
plt.ylabel(r'$\theta_1$')
plt.xticks(x_grid)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6, 3))
plt.title(r'$\text{График роста неполного правдоподобия} \,\,\mathcal{L}$' 
          '\nдля первого набора начальных условий')
plt.plot(x1, lhd_list1, color='darkred')
plt.xlabel('Номер итерации') 
plt.ylabel(r'$\mathcal{L}$')
plt.xticks(x_grid)
plt.show()
